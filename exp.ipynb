# %%
import json

# %%
file = open('MotionData/InHandStaying/in_hand_staying_1.json')
data = json.load(file)
data
# Out:
# [{'attitude': {'pitch': 0.6314630718086733,
#    'roll': 0.12974368361962305,
#    'yaw': 0.0824764819694851},
#   'gravity': {'x': 0.10443095117807388,
#    'y': -0.5903263092041016,
#    'z': -0.800380527973175},
#   'rotationRate': {'x': -0.05356500670313835,
#    'y': 0.0009007207117974758,
#    'z': -0.024899454787373543},
#   'timestamp': 49824966651041,
#   'userAcceleration': {'x': -0.006133869290351868,
#    'y': -0.014959275722503662,
#    'z': 0.0020101070404052734}},
#  {'attitude': {'pitch': 0.6302145743546742,
#    'roll': 0.13005513499341542,
#    'yaw': 0.07810030216133096},
#   'gravity': {'x': 0.10477572679519653,
#    'y': -0.5893180966377258,
#    'z': -0.8010781407356262},
#   'rotationRate': {'x': -0.02040296420454979,
#    'y': -0.016362681984901428,
#    'z': 0.008341073989868164},
#   'timestamp': 49824966651041,
#   'userAcceleration': {'x': 0.03110376000404358,
#    'y': 0.01108640432357788,
#    'z': 0.0038216114044189453}},
# ...
